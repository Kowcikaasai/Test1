# %% [markdown]
# <a href="https://colab.research.google.com/github/Kowcikaasai/Test1/blob/main/PythonBasics_Day1_KA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # PYTHON BASICS
# ## Data types
# ## Variables
# ## String operations

# %% [markdown]
# ![Python image.jpg](data:image/jpeg;base64,...)

# %%
print("Hello World") #This line is for displaying message
# Out:
# Hello World

# %%
a = "NPower Canada " * 5

# %%
b = 5
c = 100

# %%
print(a)
print(b)
print(c)
# Out:
# NPower Canada NPower Canada NPower Canada NPower Canada NPower Canada
# 5
# 100

# %%
String1 ="Welcome to NPower Canada"
String1[18:24]
# Out:
# 'Canada'

# %%
from = 5
# Out:
#   File "<ipython-input-7-66925134b21c>", line 1
#     from = 5
#          ^
# SyntaxError: invalid syntax

# %%
a="Hello"
a
# Out:
# 'Hello'

# %%
type(a)
# Out:
# str

# %%
 String= "Name"

# %%
print(String[-3])
print(String[-2])
print(String[-1])
# Out:
# a
# m
# e

# %%
Break=0

# %%
print("ok")
# Out:
# ok

# %%
String = "Welcome to"

# %%
len(String)
# Out:
# 10

# %%
min(String)
# Out:
# ' '

# %%
max(String)
# Out:
# 't'

# %%
"to" in String
# Out:
# True

# %%
"to" not in String
# Out:
# False

# %%
String = "2657478"

# %%
String.isalnum()
# Out:
# True

# %%
String.isalpha()
# Out:
# False

# %%
String.isdigit()
# Out:
# True

# %%
String.isidentifier()
# Out:
# False

# %%
String.islower()
# Out:
# False

# %%
String.isupper()
# Out:
# False

# %%
String.isspace()
# Out:
# False

# %%
String = "Welcome to NPower Canada PR 20 Cohort Canada Canada"

# %%
String.endswith("da")
# Out:
# True

# %%
String.startswith("Welcome")
# Out:
# True

# %%
String.startswith("Welcome")
# Out:
# True

# %%
String.count("Canada")
# Out:
# 3

# %%
String1 = "CCC"
print(String1.find("C"))
print(String1.rfind("C"))
# Out:
# 0
# 2

# %%
String = "Welcome to NPower Canada PR 19 Cohort Canada"

# %%
String.capitalize()
# Out:
# 'Welcome to npower canada pr 19 cohort canada'

# %%
String.lower()
# Out:
# 'welcome to npower canada pr 19 cohort canada'

# %%
String.upper()
# Out:
# 'WELCOME TO NPOWER CANADA PR 19 COHORT CANADA'

# %%
String.title()
# Out:
# 'Welcome To Npower Canada Pr 19 Cohort Canada'

# %%
String.swapcase()
# Out:
# 'wELCOME TO npOWER cANADA pr 19 cOHORT cANADA'

# %%
String.replace("19","20")
# Out:
# 'Welcome to NPower Canada PR 20 Cohort Canada'

# %%
String
# Out:
# 'Welcome to NPower Canada PR 19 Cohort Canada'

# %%
Car = "Welcome to NPower Canada PR 20 Cohort Canada"
